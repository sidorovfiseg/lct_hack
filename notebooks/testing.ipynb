# %%
import pandas as pd
import polars as pl

# %%
df = pd.read_csv('/Users/foryourselfand/Documents/patent_hack/data/DatasetOrg.csv', sep=';', low_memory=False)

# %%
df.to_parquet('/Users/foryourselfand/Documents/patent_hack/data/DatasetOrg.parquet', index=False)

# %%
df = pd.read_parquet('/Users/foryourselfand/Documents/patent_hack/data/DatasetOrg.parquet')

# %%
df = pl.read_parquet('/Users/foryourselfand/Documents/patent_hack/data/DatasetOrg.parquet')

# %%
df.head()
# Out:
# shape: (5, 23)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ ID        ┆ Наименова ┆ Наименова ┆ ИНН       ┆ … ┆ телефоны  ┆ ФИО       ┆ Название  ┆ доп.     │
# │ компании  ┆ ние       ┆ ние       ┆ ---       ┆   ┆ СПАРК     ┆ директора ┆ должности ┆ ОКВЭД2   │
# │ ---       ┆ полное    ┆ краткое   ┆ str       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ i64       ┆ ---       ┆ ---       ┆           ┆   ┆ str       ┆ str       ┆ str       ┆ str      │
# │           ┆ str       ┆ str       ┆           ┆   ┆           ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 20154920  ┆ ГОСУДАРСТ ┆ ГКУ АО    ┆ 281800498 ┆ … ┆ 416539707 ┆ Андрусова ┆ начальник ┆ 63.11.1; │
# │           ┆ ВЕННОЕ    ┆ УСЗН ПО   ┆ 6         ┆   ┆ 1;4165397 ┆ Наталья   ┆ управлени ┆ 84.30    │
# ...

# %%
df.describe()
# Out:
# shape: (9, 24)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ statistic ┆ ID        ┆ Наименова ┆ Наименова ┆ … ┆ телефоны  ┆ ФИО       ┆ Название  ┆ доп.     │
# │ ---       ┆ компании  ┆ ние       ┆ ние       ┆   ┆ СПАРК     ┆ директора ┆ должности ┆ ОКВЭД2   │
# │ str       ┆ ---       ┆ полное    ┆ краткое   ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆ f64       ┆ ---       ┆ ---       ┆   ┆ str       ┆ str       ┆ str       ┆ str      │
# │           ┆           ┆ str       ┆ str       ┆   ┆           ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ count     ┆ 3.1835226 ┆ 31752937  ┆ 31748656  ┆ … ┆ 7309685   ┆ 16262762  ┆ 16261312  ┆ 10183731 │
# │           ┆ e7        ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# ...

# %%
usefull_models_df = pd.read_excel('/Users/foryourselfand/Documents/patent_hack/data/База по полезным моделям.xlsx')

# %%
usefull_models_df.head()
# Out:
#   registration number registration date  application number application date  \
# 0             ?223746        2024-03-01        2.023129e+09       2023-11-07
# 1              100021        2010-12-10        2.010137e+09       2010-09-02
# 2              100030        2010-12-10        2.010120e+09       2010-05-19
# 3              100081        2010-12-10        2.010118e+09       2010-04-28
# 4              100090        2010-12-10        2.010133e+09       2010-08-04
#
#                                              authors authors in latin  \
# 0  Войлошников Диомид Константинович (RU)Михайлов...              NaN
# 1                      Шакеров Равиль Аббясович (RU)              NaN
# 2  Носенко Лев Евгеньевич (RU)Контарь Александр Е...              NaN
# 3                     Ахмедов Сергей Норматович (RU)              NaN
# 4  Шаферман Илья Михайлович (RU)Гитман Эдуард Мар...              NaN
#
#                                       patent holders patent holders in latin  \
# ...

# %%
usefull_models_df.to_parquet('/Users/foryourselfand/Documents/patent_hack/data/База по полезным моделям.parquet', index=False)

# %%
# /Users/foryourselfand/Documents/patent_hack/data/База по промышленным образцам.xlsx
industrial_designs_df = pd.read_excel('/Users/foryourselfand/Documents/patent_hack/data/База по промышленным образцам.xlsx')

# %%
industrial_designs_df.head()
# Out:
#    registration number registration date  application number application date  \
# 0               100000        2016-08-29        2.015504e+09       2015-10-29
# 1               100001        2016-08-29        2.015504e+09       2015-10-29
# 2               100002        2016-08-29        2.015504e+09       2015-11-19
# 3               100003        2016-08-29        2.015504e+09       2015-12-04
# 4               100004        2016-08-29        2.015505e+09       2015-12-22
#
#                                              authors authors in latin  \
# 0                         Исаев Руслан Гимиевич (RU)              NaN
# 1                   Клинецкий Евгений Федорович (RU)              NaN
# 2  Кудрявцев Андрей Юрьевич (RU)Эрнандес Серхио (RU)              NaN
# 3  Бушон Дмитрий Владимирович (RU)Бушон Эккахарт ...              NaN
# 4  Тикменов Василий Николаевич (RU)Скляров Сергей...              NaN
#
# ...

# %%
industrial_designs_df.to_parquet('/Users/foryourselfand/Documents/patent_hack/data/База по промышленным образцам.parquet', index=False)

# %%
# /Users/foryourselfand/Documents/patent_hack/data/Классификация организаций.xlsx
classification_df = pd.read_excel('/Users/foryourselfand/Documents/patent_hack/data/Классификация организаций.xlsx')

# %%
classification_df.head()
# Out:
#             ObjectType  CompanyID          INN  \
# 0  Научные организации    1633389  7704068008'
# 1  Научные организации    1677421  7704077771'
# 2  Научные организации    1662847  7706019535'
# 3  Научные организации    1633451  7706037421'
# 4  Научные организации    1633355  7706042076'
#
#                                                 Name
# 0                           Институт языкознания РАН
# 1  Московский педагогический государственный унив...
# 2  Национальный исследовательский технологический...
# 3            Почвенный институт имени В.В. Докучаева
# 4  Институт геологии рудных месторождений, петрог...

# %%
classification_df.to_parquet('/Users/foryourselfand/Documents/patent_hack/data/Классификация организаций.parquet', index=False)

# %%
# /Users/foryourselfand/Documents/patent_hack/data/База по изобретениям.xlsx
inventions_df = pd.read_excel('/Users/foryourselfand/Documents/patent_hack/data/База по изобретениям.xlsx')

# %%
inventions_df.head()
# Out:
#   registration number registration date application number application date  \
# 0            ?2273575          20060410         2004114034         20040512
# 1            ?2544582          20150211         2013158173         20131227
# 2             1002282        1983-03-07            3264511       1981-04-14
# 3             1323479        1987-07-15            3971160       1985-11-01
# 4             1733422                --                NaN               --
#
#                                              authors authors in latin  \
# 0  Омельяненко Игорь Александрович (UA)Приходько ...              NaN
# 1                       Квасенков Олег Иванович (RU)              NaN
# 2  Коврайский Андрей ЕвгеньевичНефедов Евгений Се...              NaN
# 3                     МУРАВЬЕВ ВАЛЕРИЙ АЛЕКСАНДРОВИЧ              NaN
# 4                                                NaN              NaN
#
#                                       patent holders patent holders in latin  \
# ...

# %%
inventions_df.to_parquet('/Users/foryourselfand/Documents/patent_hack/data/База по изобретениям.parquet', index=False)
